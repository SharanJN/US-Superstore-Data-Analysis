# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df = pd.read_csv('US Superstore.csv', encoding = 'latin-1')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format = 'mixed')

# %%
grouped = df.groupby(['Customer ID', 'Segment', 'Sub-Category', 'Category']).agg(
    No_of_Orders = ('Order ID', 'nunique'),
    Total_Quantity = ('Quantity', 'sum'),
).reset_index()

# %%
orderDates = df.groupby(['Customer ID', 'Sub-Category'])['Order Date'].apply(list).reset_index()

# %%
orderDates
# Out:
#      Customer ID Sub-Category  \
# 0       AA-10315  Accessories
# 1       AA-10315   Appliances
# 2       AA-10315      Binders
# 3       AA-10315    Fasteners
# 4       AA-10315  Furnishings
# ...          ...          ...
# 5997    ZD-21925          Art
# 5998    ZD-21925      Binders
# 5999    ZD-21925  Furnishings
# 6000    ZD-21925        Paper
# 6001    ZD-21925       Phones
#
#                                              Order Date
# 0                                 [2016-03-03 00:00:00]
# 1            [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 2            [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 3                                 [2016-03-03 00:00:00]
# 4                                 [2014-09-15 00:00:00]
# ...                                                 ...
# 5997                              [2014-08-27 00:00:00]
# 5998                              [2014-08-27 00:00:00]
# 5999         [2016-05-05 00:00:00, 2016-03-04 00:00:00]
# 6000                              [2016-08-07 00:00:00]
# 6001  [2014-08-27 00:00:00, 2016-08-07 00:00:00, 201...
#
# [6002 rows x 3 columns]

# %%
mergedDates = pd.merge(grouped, orderDates, on = ['Customer ID', 'Sub-Category'], how = 'left')

# %%
mergedDates
# Out:
#      Customer ID   Segment Sub-Category         Category  No_of_Orders  \
# 0       AA-10315  Consumer  Accessories       Technology             1
# 1       AA-10315  Consumer   Appliances  Office Supplies             2
# 2       AA-10315  Consumer      Binders  Office Supplies             2
# 3       AA-10315  Consumer    Fasteners  Office Supplies             1
# 4       AA-10315  Consumer  Furnishings        Furniture             1
# ...          ...       ...          ...              ...           ...
# 5997    ZD-21925  Consumer          Art  Office Supplies             1
# 5998    ZD-21925  Consumer      Binders  Office Supplies             1
# 5999    ZD-21925  Consumer  Furnishings        Furniture             2
# 6000    ZD-21925  Consumer        Paper  Office Supplies             1
# 6001    ZD-21925  Consumer       Phones       Technology             3
#
#       Total_Quantity                                         Order Date
# 0                  7                              [2016-03-03 00:00:00]
# 1                  5         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 2                  4         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 3                  1                              [2016-03-03 00:00:00]
# 4                  2                              [2014-09-15 00:00:00]
# ...              ...                                                ...
# 5997               2                              [2014-08-27 00:00:00]
# 5998               4                              [2014-08-27 00:00:00]
# 5999               9         [2016-05-05 00:00:00, 2016-03-04 00:00:00]
# 6000               2                              [2016-08-07 00:00:00]
# 6001              12  [2014-08-27 00:00:00, 2016-08-07 00:00:00, 201...
#
# [6002 rows x 7 columns]

# %%
def calculateGaps(orderDates):
    uniqueDates = sorted(set(orderDates))

    if len(uniqueDates) > 1:
        gaps = [(uniqueDates[i] - uniqueDates[i-1]).days for i in range(1, len(uniqueDates))]
        minGap = min(gaps)
        maxGap = max(gaps)
        avgGap = sum(gaps) / len(gaps)
    else:
        minGap = maxGap = avgGap = 0
    return pd.Series([minGap, maxGap, avgGap], index = ['Minimum Gap', 'Maximum Gap', 'Average Gap'])

mergedDates[['Minimum Gaps', 'Maximum Gaps', 'Average Gaps']] = mergedDates['Order Date'].apply(calculateGaps)

# %%
firstDate = df.groupby('Customer ID')['Order Date'].min().reset_index()

# %%
firstDates = firstDate.rename(columns = {
    'Order Date' : 'First Date of Purchase'})

# %%
lastDate = df.groupby('Customer ID')['Order Date'].max().reset_index()

# %%
lastDates = lastDate.rename(columns = {
    'Order Date' : 'Last Date of Purchase'})

# %%
newMerged = pd.merge(mergedDates, firstDates, on = 'Customer ID', how = 'right')

# %%
newMerged = pd.merge(newMerged, lastDates, on = 'Customer ID', how = 'right')

# %%
newMerged
# Out:
#      Customer ID   Segment Sub-Category         Category  No_of_Orders  \
# 0       AA-10315  Consumer  Accessories       Technology             1
# 1       AA-10315  Consumer   Appliances  Office Supplies             2
# 2       AA-10315  Consumer      Binders  Office Supplies             2
# 3       AA-10315  Consumer    Fasteners  Office Supplies             1
# 4       AA-10315  Consumer  Furnishings        Furniture             1
# ...          ...       ...          ...              ...           ...
# 5997    ZD-21925  Consumer          Art  Office Supplies             1
# 5998    ZD-21925  Consumer      Binders  Office Supplies             1
# 5999    ZD-21925  Consumer  Furnishings        Furniture             2
# 6000    ZD-21925  Consumer        Paper  Office Supplies             1
# 6001    ZD-21925  Consumer       Phones       Technology             3
#
#       Total_Quantity                                         Order Date  \
# 0                  7                              [2016-03-03 00:00:00]
# 1                  5         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 2                  4         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 3                  1                              [2016-03-03 00:00:00]
# 4                  2                              [2014-09-15 00:00:00]
# ...              ...                                                ...
# 5997               2                              [2014-08-27 00:00:00]
# 5998               4                              [2014-08-27 00:00:00]
# 5999               9         [2016-05-05 00:00:00, 2016-03-04 00:00:00]
# 6000               2                              [2016-08-07 00:00:00]
# 6001              12  [2014-08-27 00:00:00, 2016-08-07 00:00:00, 201...
#
#       Minimum Gaps  Maximum Gaps  Average Gaps First Date of Purchase  \
# 0              0.0           0.0           0.0             2014-03-31
# 1           1186.0        1186.0        1186.0             2014-03-31
# 2           1186.0        1186.0        1186.0             2014-03-31
# 3              0.0           0.0           0.0             2014-03-31
# 4              0.0           0.0           0.0             2014-03-31
# ...            ...           ...           ...                    ...
# 5997           0.0           0.0           0.0             2014-08-27
# 5998           0.0           0.0           0.0             2014-08-27
# 5999          62.0          62.0          62.0             2014-08-27
# 6000           0.0           0.0           0.0             2014-08-27
# 6001         156.0         555.0         355.5             2014-08-27
#
#      Last Date of Purchase
# 0               2017-06-29
# 1               2017-06-29
# 2               2017-06-29
# 3               2017-06-29
# 4               2017-06-29
# ...                    ...
# 5997            2017-11-06
# 5998            2017-11-06
# 5999            2017-11-06
# 6000            2017-11-06
# 6001            2017-11-06
#
# [6002 rows x 12 columns]

# %%
lastDate = '2017-12-31'
lastDate = pd.to_datetime(lastDate)

# %%
newMerged['Days Since Last Purchase'] = (lastDate - newMerged['Last Date of Purchase']).dt.days

# %%
lconsumerCustomers = newMerged[newMerged['Segment'] == 'Consumer']
lcorporateCustomers = newMerged[newMerged['Segment'] == 'Corporate']
lhomeofficeCustomers = newMerged[newMerged['Segment'] == 'Home Office']

# %%
consumerCount = 164
corporateCount = 143
homeofficeCount = 126

# %%
def lconflagCustomer(row):
    if row['Average Gaps'] == 0:
        if row['Days Since Last Purchase'] < 365:
            return 'Yes'
        else:
            return 'No'
    elif row['Average Gaps'] > consumerCount or row['Average Gaps'] == consumerCount:
        if row['Days Since Last Purchase'] < 365: 
            return 'Yes'
        else:
            return 'No'
    elif row['Average Gaps'] < consumerCount:
        return 'No'

lconsumerCustomers['Flagged 1'] = lconsumerCustomers.apply(lconflagCustomer, axis = 1)
lconsumerCustomers
# Out:
# C:\Users\shara\AppData\Local\Temp\ipykernel_33488\3607745899.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lconsumerCustomers['Flagged 1'] = lconsumerCustomers.apply(lconflagCustomer, axis = 1)
#      Customer ID   Segment Sub-Category         Category  No_of_Orders  \
# 0       AA-10315  Consumer  Accessories       Technology             1
# 1       AA-10315  Consumer   Appliances  Office Supplies             2
# 2       AA-10315  Consumer      Binders  Office Supplies             2
# 3       AA-10315  Consumer    Fasteners  Office Supplies             1
# 4       AA-10315  Consumer  Furnishings        Furniture             1
# ...          ...       ...          ...              ...           ...
# 5997    ZD-21925  Consumer          Art  Office Supplies             1
# 5998    ZD-21925  Consumer      Binders  Office Supplies             1
# 5999    ZD-21925  Consumer  Furnishings        Furniture             2
# 6000    ZD-21925  Consumer        Paper  Office Supplies             1
# 6001    ZD-21925  Consumer       Phones       Technology             3
#
#       Total_Quantity                                         Order Date  \
# 0                  7                              [2016-03-03 00:00:00]
# 1                  5         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 2                  4         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 3                  1                              [2016-03-03 00:00:00]
# 4                  2                              [2014-09-15 00:00:00]
# ...              ...                                                ...
# 5997               2                              [2014-08-27 00:00:00]
# 5998               4                              [2014-08-27 00:00:00]
# 5999               9         [2016-05-05 00:00:00, 2016-03-04 00:00:00]
# 6000               2                              [2016-08-07 00:00:00]
# 6001              12  [2014-08-27 00:00:00, 2016-08-07 00:00:00, 201...
#
#       Minimum Gaps  Maximum Gaps  Average Gaps First Date of Purchase  \
# 0              0.0           0.0           0.0             2014-03-31
# 1           1186.0        1186.0        1186.0             2014-03-31
# 2           1186.0        1186.0        1186.0             2014-03-31
# 3              0.0           0.0           0.0             2014-03-31
# 4              0.0           0.0           0.0             2014-03-31
# ...            ...           ...           ...                    ...
# 5997           0.0           0.0           0.0             2014-08-27
# 5998           0.0           0.0           0.0             2014-08-27
# 5999          62.0          62.0          62.0             2014-08-27
# 6000           0.0           0.0           0.0             2014-08-27
# 6001         156.0         555.0         355.5             2014-08-27
#
#      Last Date of Purchase  Days Since Last Purchase Flagged 1
# 0               2017-06-29                       185       Yes
# 1               2017-06-29                       185       Yes
# 2               2017-06-29                       185       Yes
# 3               2017-06-29                       185       Yes
# 4               2017-06-29                       185       Yes
# ...                    ...                       ...       ...
# 5997            2017-11-06                        55       Yes
# 5998            2017-11-06                        55       Yes
# 5999            2017-11-06                        55        No
# 6000            2017-11-06                        55       Yes
# 6001            2017-11-06                        55       Yes
#
# [3124 rows x 14 columns]

# %%
def lcorflagCustomer(row):
    if row['Average Gaps'] == 0:
        if row['Days Since Last Purchase'] < 365:
            return 'Yes'
        else:
            return 'No'
    elif row['Average Gaps'] > corporateCount or row['Average Gaps'] == corporateCount:
        if row['Days Since Last Purchase'] < 365: 
            return 'Yes'
        else:
            return 'No'
    elif row['Average Gaps'] < corporateCount:
        return 'No'

lcorporateCustomers['Flagged 1'] = lcorporateCustomers.apply(lcorflagCustomer, axis = 1)
lcorporateCustomers
# Out:
# C:\Users\shara\AppData\Local\Temp\ipykernel_33488\1251782408.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lcorporateCustomers['Flagged 1'] = lcorporateCustomers.apply(lcorflagCustomer, axis = 1)
#      Customer ID    Segment Sub-Category         Category  No_of_Orders  \
# 77      AB-10600  Corporate  Accessories       Technology             1
# 78      AB-10600  Corporate      Binders  Office Supplies             2
# 79      AB-10600  Corporate       Chairs        Furniture             1
# 80      AB-10600  Corporate  Furnishings        Furniture             1
# 81      AB-10600  Corporate       Labels  Office Supplies             1
# ...          ...        ...          ...              ...           ...
# 5979    YS-21880  Corporate       Chairs        Furniture             1
# 5980    YS-21880  Corporate    Envelopes  Office Supplies             1
# 5981    YS-21880  Corporate  Furnishings        Furniture             1
# 5982    YS-21880  Corporate      Storage  Office Supplies             4
# 5983    YS-21880  Corporate       Tables        Furniture             1
#
#       Total_Quantity                                         Order Date  \
# 77                 6                              [2017-10-11 00:00:00]
# 78                19         [2017-10-11 00:00:00, 2014-11-18 00:00:00]
# 79                 4                              [2017-10-11 00:00:00]
# 80                 2                              [2015-11-30 00:00:00]
# 81                 3                              [2015-02-18 00:00:00]
# ...              ...                                                ...
# 5979               6                              [2017-04-13 00:00:00]
# 5980               9                              [2015-07-25 00:00:00]
# 5981               3                              [2017-08-18 00:00:00]
# 5982              19  [2017-12-21 00:00:00, 2015-12-01 00:00:00, 201...
# 5983               2                              [2015-07-25 00:00:00]
#
#       Minimum Gaps  Maximum Gaps  Average Gaps First Date of Purchase  \
# 77             0.0           0.0      0.000000             2014-11-18
# 78          1058.0        1058.0   1058.000000             2014-11-18
# 79             0.0           0.0      0.000000             2014-11-18
# 80             0.0           0.0      0.000000             2014-11-18
# 81             0.0           0.0      0.000000             2014-11-18
# ...            ...           ...           ...                    ...
# 5979           0.0           0.0      0.000000             2015-07-25
# 5980           0.0           0.0      0.000000             2015-07-25
# 5981           0.0           0.0      0.000000             2015-07-25
# 5982         111.0         626.0    287.333333             2015-07-25
# 5983           0.0           0.0      0.000000             2015-07-25
#
#      Last Date of Purchase  Days Since Last Purchase Flagged 1
# 77              2017-10-11                        81       Yes
# 78              2017-10-11                        81       Yes
# 79              2017-10-11                        81       Yes
# 80              2017-10-11                        81       Yes
# 81              2017-10-11                        81       Yes
# ...                    ...                       ...       ...
# 5979            2017-12-21                        10       Yes
# 5980            2017-12-21                        10       Yes
# 5981            2017-12-21                        10       Yes
# 5982            2017-12-21                        10       Yes
# 5983            2017-12-21                        10       Yes
#
# [1804 rows x 14 columns]

# %%
def lhomeofficeflagCustomer(row):
    if row['Average Gaps'] == 0:
        if row['Days Since Last Purchase'] < 365:
            return 'Yes'
        else:
            return 'No'
    elif row['Average Gaps'] > homeofficeCount or row['Average Gaps'] == homeofficeCount:
        if row['Days Since Last Purchase'] < 365: 
            return 'Yes'
        else:
            return 'No'
    elif row['Average Gaps'] < homeofficeCount:
        return 'No'
        
lhomeofficeCustomers['Flagged 1'] = lhomeofficeCustomers.apply(lhomeofficeflagCustomer, axis = 1)
lhomeofficeCustomers
# Out:
# C:\Users\shara\AppData\Local\Temp\ipykernel_33488\2842758072.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lhomeofficeCustomers['Flagged 1'] = lhomeofficeCustomers.apply(lhomeofficeflagCustomer, axis = 1)
#      Customer ID      Segment Sub-Category         Category  No_of_Orders  \
# 37      AB-10060  Home Office  Accessories       Technology             3
# 38      AB-10060  Home Office   Appliances  Office Supplies             1
# 39      AB-10060  Home Office      Binders  Office Supplies             2
# 40      AB-10060  Home Office       Chairs        Furniture             1
# 41      AB-10060  Home Office  Furnishings        Furniture             1
# ...          ...          ...          ...              ...           ...
# 5930    VT-21700  Home Office    Bookcases        Furniture             1
# 5931    VT-21700  Home Office  Furnishings        Furniture             1
# 5932    VT-21700  Home Office       Labels  Office Supplies             1
# 5933    VT-21700  Home Office       Phones       Technology             1
# 5934    VT-21700  Home Office      Storage  Office Supplies             1
#
#       Total_Quantity                                         Order Date  \
# 37                 5  [2016-01-09 00:00:00, 2017-07-05 00:00:00, 201...
# 38                 2                              [2016-03-13 00:00:00]
# 39                 9  [2016-01-09 00:00:00, 2016-01-09 00:00:00, 201...
# 40                 2                              [2017-06-11 00:00:00]
# 41                 2                              [2016-03-13 00:00:00]
# ...              ...                                                ...
# 5930               5                              [2015-05-04 00:00:00]
# 5931               5         [2015-05-04 00:00:00, 2015-05-04 00:00:00]
# 5932              10                              [2014-06-06 00:00:00]
# 5933               7         [2015-05-04 00:00:00, 2015-05-04 00:00:00]
# 5934               4                              [2015-05-04 00:00:00]
#
#       Minimum Gaps  Maximum Gaps  Average Gaps First Date of Purchase  \
# 37            24.0         519.0         271.5             2015-09-18
# 38             0.0           0.0           0.0             2015-09-18
# 39            64.0          64.0          64.0             2015-09-18
# 40             0.0           0.0           0.0             2015-09-18
# 41             0.0           0.0           0.0             2015-09-18
# ...            ...           ...           ...                    ...
# 5930           0.0           0.0           0.0             2014-06-06
# 5931           0.0           0.0           0.0             2014-06-06
# 5932           0.0           0.0           0.0             2014-06-06
# 5933           0.0           0.0           0.0             2014-06-06
# 5934           0.0           0.0           0.0             2014-06-06
#
#      Last Date of Purchase  Days Since Last Purchase Flagged 1
# 37              2017-09-16                       106       Yes
# 38              2017-09-16                       106       Yes
# 39              2017-09-16                       106        No
# 40              2017-09-16                       106       Yes
# 41              2017-09-16                       106       Yes
# ...                    ...                       ...       ...
# 5930            2015-05-04                       972        No
# 5931            2015-05-04                       972        No
# 5932            2015-05-04                       972        No
# 5933            2015-05-04                       972        No
# 5934            2015-05-04                       972        No
#
# [1074 rows x 14 columns]

# %%
def flag2(row):
    if row['Average Gaps'] > consumerCount:
        return 'Yes'
    else:
        return 'No'


lconsumerCustomers['Flagged 2'] = lconsumerCustomers.apply(flag2, axis = 1)
lconsumerCustomers
# Out:
# C:\Users\shara\AppData\Local\Temp\ipykernel_33488\2133276985.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lconsumerCustomers['Flagged 2'] = lconsumerCustomers.apply(flag2, axis = 1)
#      Customer ID   Segment Sub-Category         Category  No_of_Orders  \
# 0       AA-10315  Consumer  Accessories       Technology             1
# 1       AA-10315  Consumer   Appliances  Office Supplies             2
# 2       AA-10315  Consumer      Binders  Office Supplies             2
# 3       AA-10315  Consumer    Fasteners  Office Supplies             1
# 4       AA-10315  Consumer  Furnishings        Furniture             1
# ...          ...       ...          ...              ...           ...
# 5997    ZD-21925  Consumer          Art  Office Supplies             1
# 5998    ZD-21925  Consumer      Binders  Office Supplies             1
# 5999    ZD-21925  Consumer  Furnishings        Furniture             2
# 6000    ZD-21925  Consumer        Paper  Office Supplies             1
# 6001    ZD-21925  Consumer       Phones       Technology             3
#
#       Total_Quantity                                         Order Date  \
# 0                  7                              [2016-03-03 00:00:00]
# 1                  5         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 2                  4         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 3                  1                              [2016-03-03 00:00:00]
# 4                  2                              [2014-09-15 00:00:00]
# ...              ...                                                ...
# 5997               2                              [2014-08-27 00:00:00]
# 5998               4                              [2014-08-27 00:00:00]
# 5999               9         [2016-05-05 00:00:00, 2016-03-04 00:00:00]
# 6000               2                              [2016-08-07 00:00:00]
# 6001              12  [2014-08-27 00:00:00, 2016-08-07 00:00:00, 201...
#
#       Minimum Gaps  Maximum Gaps  Average Gaps First Date of Purchase  \
# 0              0.0           0.0           0.0             2014-03-31
# 1           1186.0        1186.0        1186.0             2014-03-31
# 2           1186.0        1186.0        1186.0             2014-03-31
# 3              0.0           0.0           0.0             2014-03-31
# 4              0.0           0.0           0.0             2014-03-31
# ...            ...           ...           ...                    ...
# 5997           0.0           0.0           0.0             2014-08-27
# 5998           0.0           0.0           0.0             2014-08-27
# 5999          62.0          62.0          62.0             2014-08-27
# 6000           0.0           0.0           0.0             2014-08-27
# 6001         156.0         555.0         355.5             2014-08-27
#
#      Last Date of Purchase  Days Since Last Purchase Flagged 1 Flagged 2
# 0               2017-06-29                       185       Yes        No
# 1               2017-06-29                       185       Yes       Yes
# 2               2017-06-29                       185       Yes       Yes
# 3               2017-06-29                       185       Yes        No
# 4               2017-06-29                       185       Yes        No
# ...                    ...                       ...       ...       ...
# 5997            2017-11-06                        55       Yes        No
# 5998            2017-11-06                        55       Yes        No
# 5999            2017-11-06                        55        No        No
# 6000            2017-11-06                        55       Yes        No
# 6001            2017-11-06                        55       Yes       Yes
#
# [3124 rows x 15 columns]

# %%
def flag2(row):
    if row['Average Gaps'] > corporateCount:
        return 'Yes'
    else:
        return 'No'


lcorporateCustomers['Flagged 2'] = lcorporateCustomers.apply(flag2, axis = 1)
lcorporateCustomers
# Out:
# C:\Users\shara\AppData\Local\Temp\ipykernel_33488\3887288817.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lcorporateCustomers['Flagged 2'] = lcorporateCustomers.apply(flag2, axis = 1)
#      Customer ID    Segment Sub-Category         Category  No_of_Orders  \
# 77      AB-10600  Corporate  Accessories       Technology             1
# 78      AB-10600  Corporate      Binders  Office Supplies             2
# 79      AB-10600  Corporate       Chairs        Furniture             1
# 80      AB-10600  Corporate  Furnishings        Furniture             1
# 81      AB-10600  Corporate       Labels  Office Supplies             1
# ...          ...        ...          ...              ...           ...
# 5979    YS-21880  Corporate       Chairs        Furniture             1
# 5980    YS-21880  Corporate    Envelopes  Office Supplies             1
# 5981    YS-21880  Corporate  Furnishings        Furniture             1
# 5982    YS-21880  Corporate      Storage  Office Supplies             4
# 5983    YS-21880  Corporate       Tables        Furniture             1
#
#       Total_Quantity                                         Order Date  \
# 77                 6                              [2017-10-11 00:00:00]
# 78                19         [2017-10-11 00:00:00, 2014-11-18 00:00:00]
# 79                 4                              [2017-10-11 00:00:00]
# 80                 2                              [2015-11-30 00:00:00]
# 81                 3                              [2015-02-18 00:00:00]
# ...              ...                                                ...
# 5979               6                              [2017-04-13 00:00:00]
# 5980               9                              [2015-07-25 00:00:00]
# 5981               3                              [2017-08-18 00:00:00]
# 5982              19  [2017-12-21 00:00:00, 2015-12-01 00:00:00, 201...
# 5983               2                              [2015-07-25 00:00:00]
#
#       Minimum Gaps  Maximum Gaps  Average Gaps First Date of Purchase  \
# 77             0.0           0.0      0.000000             2014-11-18
# 78          1058.0        1058.0   1058.000000             2014-11-18
# 79             0.0           0.0      0.000000             2014-11-18
# 80             0.0           0.0      0.000000             2014-11-18
# 81             0.0           0.0      0.000000             2014-11-18
# ...            ...           ...           ...                    ...
# 5979           0.0           0.0      0.000000             2015-07-25
# 5980           0.0           0.0      0.000000             2015-07-25
# 5981           0.0           0.0      0.000000             2015-07-25
# 5982         111.0         626.0    287.333333             2015-07-25
# 5983           0.0           0.0      0.000000             2015-07-25
#
#      Last Date of Purchase  Days Since Last Purchase Flagged 1 Flagged 2
# 77              2017-10-11                        81       Yes        No
# 78              2017-10-11                        81       Yes       Yes
# 79              2017-10-11                        81       Yes        No
# 80              2017-10-11                        81       Yes        No
# 81              2017-10-11                        81       Yes        No
# ...                    ...                       ...       ...       ...
# 5979            2017-12-21                        10       Yes        No
# 5980            2017-12-21                        10       Yes        No
# 5981            2017-12-21                        10       Yes        No
# 5982            2017-12-21                        10       Yes       Yes
# 5983            2017-12-21                        10       Yes        No
#
# [1804 rows x 15 columns]

# %%
def flag2(row):
    if row['Average Gaps'] > homeofficeCount:
        return 'Yes'
    else:
        return 'No'


lhomeofficeCustomers['Flagged 2'] = lhomeofficeCustomers.apply(flag2, axis = 1)
lhomeofficeCustomers
# Out:
# C:\Users\shara\AppData\Local\Temp\ipykernel_33488\500321446.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lhomeofficeCustomers['Flagged 2'] = lhomeofficeCustomers.apply(flag2, axis = 1)
#      Customer ID      Segment Sub-Category         Category  No_of_Orders  \
# 37      AB-10060  Home Office  Accessories       Technology             3
# 38      AB-10060  Home Office   Appliances  Office Supplies             1
# 39      AB-10060  Home Office      Binders  Office Supplies             2
# 40      AB-10060  Home Office       Chairs        Furniture             1
# 41      AB-10060  Home Office  Furnishings        Furniture             1
# ...          ...          ...          ...              ...           ...
# 5930    VT-21700  Home Office    Bookcases        Furniture             1
# 5931    VT-21700  Home Office  Furnishings        Furniture             1
# 5932    VT-21700  Home Office       Labels  Office Supplies             1
# 5933    VT-21700  Home Office       Phones       Technology             1
# 5934    VT-21700  Home Office      Storage  Office Supplies             1
#
#       Total_Quantity                                         Order Date  \
# 37                 5  [2016-01-09 00:00:00, 2017-07-05 00:00:00, 201...
# 38                 2                              [2016-03-13 00:00:00]
# 39                 9  [2016-01-09 00:00:00, 2016-01-09 00:00:00, 201...
# 40                 2                              [2017-06-11 00:00:00]
# 41                 2                              [2016-03-13 00:00:00]
# ...              ...                                                ...
# 5930               5                              [2015-05-04 00:00:00]
# 5931               5         [2015-05-04 00:00:00, 2015-05-04 00:00:00]
# 5932              10                              [2014-06-06 00:00:00]
# 5933               7         [2015-05-04 00:00:00, 2015-05-04 00:00:00]
# 5934               4                              [2015-05-04 00:00:00]
#
#       Minimum Gaps  Maximum Gaps  Average Gaps First Date of Purchase  \
# 37            24.0         519.0         271.5             2015-09-18
# 38             0.0           0.0           0.0             2015-09-18
# 39            64.0          64.0          64.0             2015-09-18
# 40             0.0           0.0           0.0             2015-09-18
# 41             0.0           0.0           0.0             2015-09-18
# ...            ...           ...           ...                    ...
# 5930           0.0           0.0           0.0             2014-06-06
# 5931           0.0           0.0           0.0             2014-06-06
# 5932           0.0           0.0           0.0             2014-06-06
# 5933           0.0           0.0           0.0             2014-06-06
# 5934           0.0           0.0           0.0             2014-06-06
#
#      Last Date of Purchase  Days Since Last Purchase Flagged 1 Flagged 2
# 37              2017-09-16                       106       Yes       Yes
# 38              2017-09-16                       106       Yes        No
# 39              2017-09-16                       106        No        No
# 40              2017-09-16                       106       Yes        No
# 41              2017-09-16                       106       Yes        No
# ...                    ...                       ...       ...       ...
# 5930            2015-05-04                       972        No        No
# 5931            2015-05-04                       972        No        No
# 5932            2015-05-04                       972        No        No
# 5933            2015-05-04                       972        No        No
# 5934            2015-05-04                       972        No        No
#
# [1074 rows x 15 columns]

# %%
rfm = df.groupby('Customer ID').agg(
    Recency=('Order Date', lambda day: (lastDate - day.max()).days),
    Frequency=('Order ID', 'nunique'),
    Monetary=('Sales', 'sum')
).reset_index()
rfm
# Out:
#     Customer ID  Recency  Frequency  Monetary
# 0      AA-10315      185          5  5563.560
# 1      AA-10375       49          9  1056.390
# 2      AA-10480      260          4  1790.512
# 3      AA-10645      234          6  5086.935
# 4      AB-10015      446          3   886.156
# ..          ...      ...        ...       ...
# 788    XP-21865       44         11  2374.658
# 789    YC-21895        5          5  5454.350
# 790    YS-21880       10          8  6720.444
# 791    ZC-21910       55         13  8025.707
# 792    ZD-21925       55          5  1493.944
#
# [793 rows x 4 columns]

# %%
rfm['Recency Score'] = pd.qcut(rfm['Recency'], 5, labels = [5,4,3,2,1])
rfm["Frequency Score"] = pd.qcut(rfm["Frequency"],5,labels=[1,2,3,4,5])
rfm["Monetary Score"] = pd.qcut(rfm["Monetary"],5,labels=[1,2,3,4,5])
rfm['RFM Score'] = rfm['Recency Score'].astype(str) + rfm['Frequency Score'].astype(str) + rfm['Monetary Score'].astype(str)

# %% [markdown]
# ## Cross-over Points for Recency:

# %%
recencyQuantiles = rfm['Recency'].quantile([0.2, 0.4, 0.6, 0.8, 1])
recencyQuantiles.reset_index()
# Out:
#    index  Recency
# 0    0.2     32.4
# 1    0.4     69.0
# 2    0.6    127.0
# 3    0.8    268.4
# 4    1.0   1166.0

# %% [markdown]
# ## Cross-over Points for Frequency:

# %%
frequencyQuantiles = rfm['Frequency'].quantile([0.2, 0.4, 0.6, 0.8, 1])
frequencyQuantiles.reset_index()
# Out:
#    index  Frequency
# 0    0.2        4.0
# 1    0.4        5.0
# 2    0.6        7.0
# 3    0.8        8.6
# 4    1.0       17.0

# %% [markdown]
# ## Cross-over Points for Monetary:

# %%
monetaryQuantiles = rfm['Monetary'].quantile([0.2, 0.4, 0.6, 0.8, 1])
monetaryQuantiles.reset_index()
# Out:
#    index    Monetary
# 0    0.2    961.5406
# 1    0.4   1739.4324
# 2    0.6   2750.7480
# 3    0.8   4282.6344
# 4    1.0  25043.0500

# %%
seg_map = {
    r'[1-2][1-2]': 'Hibernating/At Risk',
    r'[1-2][3-5]': 'Can\'t Lose',
    r'3[1-3]': 'Need Attention',
    r'[4-5][1-3]': 'Promising/Potential Loyalists',
    r'[4-5][4-5]': 'Champions/Loyal Customers',
    r'51': 'New Customers',
    r'3[4-5]': 'Frequent but not Recent',
}

# %%
rfm['RFM Segment'] = rfm['Recency Score'].astype(str) + rfm['Frequency Score'].astype(str)
rfm['RFM Segment'] = rfm['RFM Segment'].replace(seg_map, regex=True)
rfm
# Out:
#     Customer ID  Recency  Frequency  Monetary Recency Score Frequency Score  \
# 0      AA-10315      185          5  5563.560             2               2
# 1      AA-10375       49          9  1056.390             4               5
# 2      AA-10480      260          4  1790.512             2               1
# 3      AA-10645      234          6  5086.935             2               3
# 4      AB-10015      446          3   886.156             1               1
# ..          ...      ...        ...       ...           ...             ...
# 788    XP-21865       44         11  2374.658             4               5
# 789    YC-21895        5          5  5454.350             5               2
# 790    YS-21880       10          8  6720.444             5               4
# 791    ZC-21910       55         13  8025.707             4               5
# 792    ZD-21925       55          5  1493.944             4               2
#
#     Monetary Score RFM Score                    RFM Segment
# 0                5       225            Hibernating/At Risk
# 1                2       452      Champions/Loyal Customers
# 2                3       213            Hibernating/At Risk
# 3                5       235                     Can't Lose
# 4                1       111            Hibernating/At Risk
# ..             ...       ...                            ...
# 788              3       453      Champions/Loyal Customers
# 789              5       525  Promising/Potential Loyalists
# 790              5       545      Champions/Loyal Customers
# 791              5       455      Champions/Loyal Customers
# 792              2       422  Promising/Potential Loyalists
#
# [793 rows x 9 columns]

# %%
customerSegment = df.groupby('Customer ID')['Segment'].unique().reset_index()

# %%
customerSegment
# Out:
#     Customer ID      Segment
# 0      AA-10315   [Consumer]
# 1      AA-10375   [Consumer]
# 2      AA-10480   [Consumer]
# 3      AA-10645   [Consumer]
# 4      AB-10015   [Consumer]
# ..          ...          ...
# 788    XP-21865   [Consumer]
# 789    YC-21895  [Corporate]
# 790    YS-21880  [Corporate]
# 791    ZC-21910   [Consumer]
# 792    ZD-21925   [Consumer]
#
# [793 rows x 2 columns]

# %%
rfm = pd.merge(customerSegment, rfm, on = 'Customer ID', how = 'left')

# %%
rfm
# Out:
#     Customer ID      Segment  Recency  Frequency  Monetary Recency Score  \
# 0      AA-10315   [Consumer]      185          5  5563.560             2
# 1      AA-10375   [Consumer]       49          9  1056.390             4
# 2      AA-10480   [Consumer]      260          4  1790.512             2
# 3      AA-10645   [Consumer]      234          6  5086.935             2
# 4      AB-10015   [Consumer]      446          3   886.156             1
# ..          ...          ...      ...        ...       ...           ...
# 788    XP-21865   [Consumer]       44         11  2374.658             4
# 789    YC-21895  [Corporate]        5          5  5454.350             5
# 790    YS-21880  [Corporate]       10          8  6720.444             5
# 791    ZC-21910   [Consumer]       55         13  8025.707             4
# 792    ZD-21925   [Consumer]       55          5  1493.944             4
#
#     Frequency Score Monetary Score RFM Score                    RFM Segment
# 0                 2              5       225            Hibernating/At Risk
# 1                 5              2       452      Champions/Loyal Customers
# 2                 1              3       213            Hibernating/At Risk
# 3                 3              5       235                     Can't Lose
# 4                 1              1       111            Hibernating/At Risk
# ..              ...            ...       ...                            ...
# 788               5              3       453      Champions/Loyal Customers
# 789               2              5       525  Promising/Potential Loyalists
# 790               4              5       545      Champions/Loyal Customers
# 791               5              5       455      Champions/Loyal Customers
# 792               2              2       422  Promising/Potential Loyalists
#
# [793 rows x 10 columns]

# %%
newColumns = ['Customer ID', 'RFM Score' ,'RFM Segment']
mergeThese = rfm[newColumns]

# %%
mergeThese
# Out:
#     Customer ID RFM Score                    RFM Segment
# 0      AA-10315       225            Hibernating/At Risk
# 1      AA-10375       452      Champions/Loyal Customers
# 2      AA-10480       213            Hibernating/At Risk
# 3      AA-10645       235                     Can't Lose
# 4      AB-10015       111            Hibernating/At Risk
# ..          ...       ...                            ...
# 788    XP-21865       453      Champions/Loyal Customers
# 789    YC-21895       525  Promising/Potential Loyalists
# 790    YS-21880       545      Champions/Loyal Customers
# 791    ZC-21910       455      Champions/Loyal Customers
# 792    ZD-21925       422  Promising/Potential Loyalists
#
# [793 rows x 3 columns]

# %%
ConsumerCustomersRFM = rfm[rfm['Segment'] == 'Consumer']
CorporateCustomersRFM = rfm[rfm['Segment'] == 'Corporate']
HomeOfficeCustomerRFM = rfm[rfm['Segment'] == 'Home Office']

# %%
ConsumerCustomersRFM
# Out:
#     Customer ID     Segment  Recency  Frequency  Monetary Recency Score  \
# 0      AA-10315  [Consumer]      185          5  5563.560             2
# 1      AA-10375  [Consumer]       49          9  1056.390             4
# 2      AA-10480  [Consumer]      260          4  1790.512             2
# 3      AA-10645  [Consumer]      234          6  5086.935             2
# 4      AB-10015  [Consumer]      446          3   886.156             1
# ..          ...         ...      ...        ...       ...           ...
# 784    VS-21820  [Consumer]      222          4  1055.981             2
# 787    WB-21850  [Consumer]       50         11  6160.102             4
# 788    XP-21865  [Consumer]       44         11  2374.658             4
# 791    ZC-21910  [Consumer]       55         13  8025.707             4
# 792    ZD-21925  [Consumer]       55          5  1493.944             4
#
#     Frequency Score Monetary Score RFM Score                    RFM Segment
# 0                 2              5       225            Hibernating/At Risk
# 1                 5              2       452      Champions/Loyal Customers
# 2                 1              3       213            Hibernating/At Risk
# 3                 3              5       235                     Can't Lose
# 4                 1              1       111            Hibernating/At Risk
# ..              ...            ...       ...                            ...
# 784               1              2       212            Hibernating/At Risk
# 787               5              5       455      Champions/Loyal Customers
# 788               5              3       453      Champions/Loyal Customers
# 791               5              5       455      Champions/Loyal Customers
# 792               2              2       422  Promising/Potential Loyalists
#
# [409 rows x 10 columns]

# %%
lconsumerCustomers
# Out:
#      Customer ID   Segment Sub-Category         Category  No_of_Orders  \
# 0       AA-10315  Consumer  Accessories       Technology             1
# 1       AA-10315  Consumer   Appliances  Office Supplies             2
# 2       AA-10315  Consumer      Binders  Office Supplies             2
# 3       AA-10315  Consumer    Fasteners  Office Supplies             1
# 4       AA-10315  Consumer  Furnishings        Furniture             1
# ...          ...       ...          ...              ...           ...
# 5997    ZD-21925  Consumer          Art  Office Supplies             1
# 5998    ZD-21925  Consumer      Binders  Office Supplies             1
# 5999    ZD-21925  Consumer  Furnishings        Furniture             2
# 6000    ZD-21925  Consumer        Paper  Office Supplies             1
# 6001    ZD-21925  Consumer       Phones       Technology             3
#
#       Total_Quantity                                         Order Date  \
# 0                  7                              [2016-03-03 00:00:00]
# 1                  5         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 2                  4         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 3                  1                              [2016-03-03 00:00:00]
# 4                  2                              [2014-09-15 00:00:00]
# ...              ...                                                ...
# 5997               2                              [2014-08-27 00:00:00]
# 5998               4                              [2014-08-27 00:00:00]
# 5999               9         [2016-05-05 00:00:00, 2016-03-04 00:00:00]
# 6000               2                              [2016-08-07 00:00:00]
# 6001              12  [2014-08-27 00:00:00, 2016-08-07 00:00:00, 201...
#
#       Minimum Gaps  Maximum Gaps  Average Gaps First Date of Purchase  \
# 0              0.0           0.0           0.0             2014-03-31
# 1           1186.0        1186.0        1186.0             2014-03-31
# 2           1186.0        1186.0        1186.0             2014-03-31
# 3              0.0           0.0           0.0             2014-03-31
# 4              0.0           0.0           0.0             2014-03-31
# ...            ...           ...           ...                    ...
# 5997           0.0           0.0           0.0             2014-08-27
# 5998           0.0           0.0           0.0             2014-08-27
# 5999          62.0          62.0          62.0             2014-08-27
# 6000           0.0           0.0           0.0             2014-08-27
# 6001         156.0         555.0         355.5             2014-08-27
#
#      Last Date of Purchase  Days Since Last Purchase Flagged 1 Flagged 2
# 0               2017-06-29                       185       Yes        No
# 1               2017-06-29                       185       Yes       Yes
# 2               2017-06-29                       185       Yes       Yes
# 3               2017-06-29                       185       Yes        No
# 4               2017-06-29                       185       Yes        No
# ...                    ...                       ...       ...       ...
# 5997            2017-11-06                        55       Yes        No
# 5998            2017-11-06                        55       Yes        No
# 5999            2017-11-06                        55        No        No
# 6000            2017-11-06                        55       Yes        No
# 6001            2017-11-06                        55       Yes       Yes
#
# [3124 rows x 15 columns]

# %%
ConsumerCustomersRFM = ConsumerCustomersRFM.drop(columns = {'Segment'})
CorporateCustomersRFM = CorporateCustomersRFM.drop(columns = {'Segment'})
HomeOfficeCustomerRFM = HomeOfficeCustomerRFM.drop(columns = {'Segment'})

# %%
lconsumerCustomers = pd.merge(lconsumerCustomers, ConsumerCustomersRFM, on = 'Customer ID', how = 'left')
lcorporateCustomers = pd.merge(lcorporateCustomers, CorporateCustomersRFM, on = 'Customer ID', how = 'left')
lhomeofficeCustomers = pd.merge(lhomeofficeCustomers, HomeOfficeCustomerRFM, on = 'Customer ID', how = 'left')

# %%
lconsumerCustomers
# Out:
#      Customer ID   Segment Sub-Category         Category  No_of_Orders  \
# 0       AA-10315  Consumer  Accessories       Technology             1
# 1       AA-10315  Consumer   Appliances  Office Supplies             2
# 2       AA-10315  Consumer      Binders  Office Supplies             2
# 3       AA-10315  Consumer    Fasteners  Office Supplies             1
# 4       AA-10315  Consumer  Furnishings        Furniture             1
# ...          ...       ...          ...              ...           ...
# 3119    ZD-21925  Consumer          Art  Office Supplies             1
# 3120    ZD-21925  Consumer      Binders  Office Supplies             1
# 3121    ZD-21925  Consumer  Furnishings        Furniture             2
# 3122    ZD-21925  Consumer        Paper  Office Supplies             1
# 3123    ZD-21925  Consumer       Phones       Technology             3
#
#       Total_Quantity                                         Order Date  \
# 0                  7                              [2016-03-03 00:00:00]
# 1                  5         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 2                  4         [2017-06-29 00:00:00, 2014-03-31 00:00:00]
# 3                  1                              [2016-03-03 00:00:00]
# 4                  2                              [2014-09-15 00:00:00]
# ...              ...                                                ...
# 3119               2                              [2014-08-27 00:00:00]
# 3120               4                              [2014-08-27 00:00:00]
# 3121               9         [2016-05-05 00:00:00, 2016-03-04 00:00:00]
# 3122               2                              [2016-08-07 00:00:00]
# 3123              12  [2014-08-27 00:00:00, 2016-08-07 00:00:00, 201...
#
#       Minimum Gaps  Maximum Gaps  Average Gaps  ... Flagged 1 Flagged 2  \
# 0              0.0           0.0           0.0  ...       Yes        No
# 1           1186.0        1186.0        1186.0  ...       Yes       Yes
# 2           1186.0        1186.0        1186.0  ...       Yes       Yes
# 3              0.0           0.0           0.0  ...       Yes        No
# 4              0.0           0.0           0.0  ...       Yes        No
# ...            ...           ...           ...  ...       ...       ...
# 3119           0.0           0.0           0.0  ...       Yes        No
# 3120           0.0           0.0           0.0  ...       Yes        No
# 3121          62.0          62.0          62.0  ...        No        No
# 3122           0.0           0.0           0.0  ...       Yes        No
# 3123         156.0         555.0         355.5  ...       Yes       Yes
#
#       Recency Frequency  Monetary  Recency Score  Frequency Score  \
# 0         185         5  5563.560              2                2
# 1         185         5  5563.560              2                2
# 2         185         5  5563.560              2                2
# 3         185         5  5563.560              2                2
# 4         185         5  5563.560              2                2
# ...       ...       ...       ...            ...              ...
# 3119       55         5  1493.944              4                2
# 3120       55         5  1493.944              4                2
# 3121       55         5  1493.944              4                2
# 3122       55         5  1493.944              4                2
# 3123       55         5  1493.944              4                2
#
#       Monetary Score RFM Score                    RFM Segment
# 0                  5       225            Hibernating/At Risk
# 1                  5       225            Hibernating/At Risk
# 2                  5       225            Hibernating/At Risk
# 3                  5       225            Hibernating/At Risk
# 4                  5       225            Hibernating/At Risk
# ...              ...       ...                            ...
# 3119               2       422  Promising/Potential Loyalists
# 3120               2       422  Promising/Potential Loyalists
# 3121               2       422  Promising/Potential Loyalists
# 3122               2       422  Promising/Potential Loyalists
# 3123               2       422  Promising/Potential Loyalists
#
# [3124 rows x 23 columns]

# %%
lcorporateCustomers
# Out:
#      Customer ID    Segment Sub-Category         Category  No_of_Orders  \
# 0       AB-10600  Corporate  Accessories       Technology             1
# 1       AB-10600  Corporate      Binders  Office Supplies             2
# 2       AB-10600  Corporate       Chairs        Furniture             1
# 3       AB-10600  Corporate  Furnishings        Furniture             1
# 4       AB-10600  Corporate       Labels  Office Supplies             1
# ...          ...        ...          ...              ...           ...
# 1799    YS-21880  Corporate       Chairs        Furniture             1
# 1800    YS-21880  Corporate    Envelopes  Office Supplies             1
# 1801    YS-21880  Corporate  Furnishings        Furniture             1
# 1802    YS-21880  Corporate      Storage  Office Supplies             4
# 1803    YS-21880  Corporate       Tables        Furniture             1
#
#       Total_Quantity                                         Order Date  \
# 0                  6                              [2017-10-11 00:00:00]
# 1                 19         [2017-10-11 00:00:00, 2014-11-18 00:00:00]
# 2                  4                              [2017-10-11 00:00:00]
# 3                  2                              [2015-11-30 00:00:00]
# 4                  3                              [2015-02-18 00:00:00]
# ...              ...                                                ...
# 1799               6                              [2017-04-13 00:00:00]
# 1800               9                              [2015-07-25 00:00:00]
# 1801               3                              [2017-08-18 00:00:00]
# 1802              19  [2017-12-21 00:00:00, 2015-12-01 00:00:00, 201...
# 1803               2                              [2015-07-25 00:00:00]
#
#       Minimum Gaps  Maximum Gaps  Average Gaps  ... Flagged 1 Flagged 2  \
# 0              0.0           0.0      0.000000  ...       Yes        No
# 1           1058.0        1058.0   1058.000000  ...       Yes       Yes
# 2              0.0           0.0      0.000000  ...       Yes        No
# 3              0.0           0.0      0.000000  ...       Yes        No
# 4              0.0           0.0      0.000000  ...       Yes        No
# ...            ...           ...           ...  ...       ...       ...
# 1799           0.0           0.0      0.000000  ...       Yes        No
# 1800           0.0           0.0      0.000000  ...       Yes        No
# 1801           0.0           0.0      0.000000  ...       Yes        No
# 1802         111.0         626.0    287.333333  ...       Yes       Yes
# 1803           0.0           0.0      0.000000  ...       Yes        No
#
#       Recency Frequency  Monetary  Recency Score  Frequency Score  \
# 0          81         4  1515.862              3                1
# 1          81         4  1515.862              3                1
# 2          81         4  1515.862              3                1
# 3          81         4  1515.862              3                1
# 4          81         4  1515.862              3                1
# ...       ...       ...       ...            ...              ...
# 1799       10         8  6720.444              5                4
# 1800       10         8  6720.444              5                4
# 1801       10         8  6720.444              5                4
# 1802       10         8  6720.444              5                4
# 1803       10         8  6720.444              5                4
#
#       Monetary Score RFM Score                RFM Segment
# 0                  2       312             Need Attention
# 1                  2       312             Need Attention
# 2                  2       312             Need Attention
# 3                  2       312             Need Attention
# 4                  2       312             Need Attention
# ...              ...       ...                        ...
# 1799               5       545  Champions/Loyal Customers
# 1800               5       545  Champions/Loyal Customers
# 1801               5       545  Champions/Loyal Customers
# 1802               5       545  Champions/Loyal Customers
# 1803               5       545  Champions/Loyal Customers
#
# [1804 rows x 23 columns]

# %%
lhomeofficeCustomers
# Out:
#      Customer ID      Segment Sub-Category         Category  No_of_Orders  \
# 0       AB-10060  Home Office  Accessories       Technology             3
# 1       AB-10060  Home Office   Appliances  Office Supplies             1
# 2       AB-10060  Home Office      Binders  Office Supplies             2
# 3       AB-10060  Home Office       Chairs        Furniture             1
# 4       AB-10060  Home Office  Furnishings        Furniture             1
# ...          ...          ...          ...              ...           ...
# 1069    VT-21700  Home Office    Bookcases        Furniture             1
# 1070    VT-21700  Home Office  Furnishings        Furniture             1
# 1071    VT-21700  Home Office       Labels  Office Supplies             1
# 1072    VT-21700  Home Office       Phones       Technology             1
# 1073    VT-21700  Home Office      Storage  Office Supplies             1
#
#       Total_Quantity                                         Order Date  \
# 0                  5  [2016-01-09 00:00:00, 2017-07-05 00:00:00, 201...
# 1                  2                              [2016-03-13 00:00:00]
# 2                  9  [2016-01-09 00:00:00, 2016-01-09 00:00:00, 201...
# 3                  2                              [2017-06-11 00:00:00]
# 4                  2                              [2016-03-13 00:00:00]
# ...              ...                                                ...
# 1069               5                              [2015-05-04 00:00:00]
# 1070               5         [2015-05-04 00:00:00, 2015-05-04 00:00:00]
# 1071              10                              [2014-06-06 00:00:00]
# 1072               7         [2015-05-04 00:00:00, 2015-05-04 00:00:00]
# 1073               4                              [2015-05-04 00:00:00]
#
#       Minimum Gaps  Maximum Gaps  Average Gaps  ... Flagged 1 Flagged 2  \
# 0             24.0         519.0         271.5  ...       Yes       Yes
# 1              0.0           0.0           0.0  ...       Yes        No
# 2             64.0          64.0          64.0  ...        No        No
# 3              0.0           0.0           0.0  ...       Yes        No
# 4              0.0           0.0           0.0  ...       Yes        No
# ...            ...           ...           ...  ...       ...       ...
# 1069           0.0           0.0           0.0  ...        No        No
# 1070           0.0           0.0           0.0  ...        No        No
# 1071           0.0           0.0           0.0  ...        No        No
# 1072           0.0           0.0           0.0  ...        No        No
# 1073           0.0           0.0           0.0  ...        No        No
#
#       Recency Frequency  Monetary  Recency Score  Frequency Score  \
# 0         106         8  7755.620              3                4
# 1         106         8  7755.620              3                4
# 2         106         8  7755.620              3                4
# 3         106         8  7755.620              3                4
# 4         106         8  7755.620              3                4
# ...       ...       ...       ...            ...              ...
# 1069      972         2  1736.596              1                1
# 1070      972         2  1736.596              1                1
# 1071      972         2  1736.596              1                1
# 1072      972         2  1736.596              1                1
# 1073      972         2  1736.596              1                1
#
#       Monetary Score RFM Score              RFM Segment
# 0                  5       345  Frequent but not Recent
# 1                  5       345  Frequent but not Recent
# 2                  5       345  Frequent but not Recent
# 3                  5       345  Frequent but not Recent
# 4                  5       345  Frequent but not Recent
# ...              ...       ...                      ...
# 1069               2       112      Hibernating/At Risk
# 1070               2       112      Hibernating/At Risk
# 1071               2       112      Hibernating/At Risk
# 1072               2       112      Hibernating/At Risk
# 1073               2       112      Hibernating/At Risk
#
# [1074 rows x 23 columns]

# %%
lconsumerCustomers.to_csv('Consumer Customers with RFM.csv')
lcorporateCustomers.to_csv('Coporate Customers with RFM.csv')
lhomeofficeCustomers.to_csv('Home Office Customers with RFM.csv')

# %% [markdown]
# ## Recency:
#
# Measures how recently a customer made a purchase.
# Here, a higher recency value indicates that the customer has made a purchase recently.
# Here, on a scale of 1-5, 5 being the lowest value, indicates that the customer has recently made a purchase. Whereas, 1 being the highest value, indicates that its been a very long time since the customer has made a purchase.
#
# ## Frequency
#
# Measures how often a customer makes purchases within a specific time frame.
# Here, a higher frequency value indicates that the customer purchases frequently.
# Here, on a scale of 1-5, 5 being the highest value, indicates that the customer purchases frequently. Whereas, 1 being the lowest value, indicates that the customer barely makes any purchases.
#
# ## Monetary
#
# Measures how much money a customer spends over a specific period.
# Here, a higher monetary value indicates that the customer has spent alot. Customers with higher monetary values contribute significantly to the company's revenue.
# Here, on a scale of 1-5, 5 being the highest value, indicates that the customer contributes significantly to the company's revenue. Whereas, 1 being the lowest value, indicates that the customer's contribution to the company's revenue is the least significant.

# %%
frequencyDistributionRFM = rfm['RFM Segment'].value_counts()
frequencyDistributionRFM = frequencyDistributionRFM.reset_index()

# %%
frequencyDistributionRFM
# Out:
#                      RFM Segment  count
# 0  Promising/Potential Loyalists    194
# 1            Hibernating/At Risk    184
# 2                     Can't Lose    132
# 3      Champions/Loyal Customers    125
# 4                 Need Attention    103
# 5        Frequent but not Recent     55

# %%
newOrder = [
    'Champions/Loyal Customers',
    'Promising/Potential Loyalists',
    "Can't Lose",
    'Frequent but not Recent',
    'Need Attention',
    'Hibernating/At Risk'
]

# %%
frequencyDistributionRFM = frequencyDistributionRFM.set_index('RFM Segment').reindex(newOrder).reset_index()
frequencyDistributionRFM
# Out:
#                      RFM Segment  count
# 0      Champions/Loyal Customers    125
# 1  Promising/Potential Loyalists    194
# 2                     Can't Lose    132
# 3        Frequent but not Recent     55
# 4                 Need Attention    103
# 5            Hibernating/At Risk    184

# %% [markdown]
# ## Hibernating/At Risk(170):
#
# These are the customers who have not made purchases recently, and are not frequent. It has been a very long time that they have visited and have made very few visits the store.
#
# ## Promising/Potential Loyalists(161):
#
# These are the customers who have made purchases recently but are either not frequent or are moderately frequent. They have visited the store several time recently, would pose as potential loyal customers.
#
# ## Champions/Loyal Customers(158):
#
# These are the customers who make frequent purchases. They contribute significantly to the company's revenue.
#
# ## Can't Lose(146):
#
# These are the customers who used to visit frequently but then, it's been a long time that they have visited the store. The company should focus on trying to grab these customer's attention.
#
# ## Need Attention(91):
#
# These are the customers who have visited quite recently, but they are moderately frequent.
#
# ## Frequent but not Recent(67):
#
# These are the customers who used to visit the store frequently.
